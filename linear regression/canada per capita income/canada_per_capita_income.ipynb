# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
url=r"C:\Users\Divyansh\Desktop\udemy machine learning\codes\linear regression\canada_per_capita_income.csv"
dataset=pd.read_csv(url)
X=dataset.iloc[:,:-1].values
y=dataset.iloc[:,-1].values

# %%
dataset.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred=regressor.predict(X_test)

# %%
plt.scatter(X_train,y_train,color="red")
plt.plot(X_train,regressor.predict(X_train),color="blue")
plt.title("year VS per capita income (US$) (Training set)")
plt.xlabel("year")
plt.ylabel("per capita income (US$)")
plt.show()

# %%
plt.scatter(X_test,y_test,color="red")
plt.plot(X_train,regressor.predict(X_train),color="black")
plt.title("year VS per capita income (US$) (Test set)")
plt.xlabel("Year")
plt.ylabel("per capita income (US$)")
plt.show()

# %%
print(regressor.coef_)
print(regressor.intercept_)
# Out:
# [838.48247458]
# -1651800.0965383372

# %%
regressor.score(X_test,y_test)
# Out:
# 0.7622063756926367

# %%
regressor.predict([[2020]])
# Out:
# array([41934.50210655])
