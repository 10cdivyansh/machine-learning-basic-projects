# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
url=r"C:\Users\Divyansh\Desktop\udemy machine learning\codes\linear regression\homeprices.csv"
dataset=pd.read_csv(url)
X=dataset.iloc[:,:-1].values
y=dataset.iloc[:,-1].values

# %%
print(X)
# Out:
# [[2600]
#  [3000]
#  [3200]
#  [3600]
#  [4000]]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred=regressor.predict(X_test)

# %%
plt.scatter(X_train,y_train,color="red")
plt.plot(X_train,regressor.predict(X_train),color="blue")
plt.title("AREA VS PRICE (Training set)")
plt.xlabel("AREA")
plt.ylabel("PRICE")
plt.show()

# %%
plt.scatter(X_test,y_test,color="red")
plt.plot(X_train,regressor.predict(X_train),color="black")
plt.title("AREA VS PRICE (Test set)")
plt.xlabel("AREA")
plt.ylabel("PRICE")
plt.show()

# %%
regressor.predict([[4000]])
# Out:
# array([724741.37931034])

# %%
url1=r"C:\Users\Divyansh\Desktop\udemy machine learning\codes\linear regression\areas.csv"
d=pd.read_csv(url1)
d.head()
# Out:
#    area
# 0  1000
# 1  1500
# 2  2300
# 3  3540
# 4  4120

# %%
pred=regressor.predict(d)
# Out:
# C:\Users\Divyansh\anaconda3\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(

# %%
print(pred)
# Out:
# [ 318706.89655172  386379.31034483  494655.17241379  662482.75862069
#   740982.75862069  800534.48275862  926405.17241379  651655.17241379
#   826250.          494655.17241379 1401465.51724138 1347327.5862069
#  1144310.34482759]

# %%
d["prices"]=pred

# %%
d.head()
# Out:
#    area         prices
# 0  1000  318706.896552
# 1  1500  386379.310345
# 2  2300  494655.172414
# 3  3540  662482.758621
# 4  4120  740982.758621

# %%
d.to_csv("predection.csv",index=False)

# %%
plt.scatter(X,y,color="red")
plt.scatter(d["area"],pred,color="blue",marker="+")
plt.plot(d["area"],pred,color="black")
plt.title("AREA VS PRICE (Test set)",fontsize=20)
plt.xlabel("AREA",fontsize=15)
plt.ylabel("PRICE",fontsize=15)
plt.show()
